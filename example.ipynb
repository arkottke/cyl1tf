# %%
import matplotlib.pyplot as plt
import numpy as np

import cyl1tf

# %%
plt.rcParams['figure.dpi'] = 150

# %%
data = np.loadtxt('tests/data/snp500.txt')

# %%
fig, ax = plt.subplots()
ax.plot(data, ':')
fig;

# %%
cyl1tf.calc_max_scale(data)
# Out:
# 37394.806491448

# %%
fit = cyl1tf.calc_fit(data, rel_scale=0.01)

# %%
fig, ax = plt.subplots()
ax.plot(data, ':', label='Data')
ax.plot(fit, '-', label='L1 Fit')
ax.legend()
fig;
